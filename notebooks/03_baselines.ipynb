# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.metrics import adjusted_rand_score

# %store -r dataset
X = dataset[0]
z_true = dataset[1]
X_pca = dataset[2]

# %%
kmeans = KMeans(n_clusters = 3, random_state= 42)
z_kmeans = kmeans.fit_predict(X_pca)

# %%
plt.figure(figsize=(6, 6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=z_kmeans, cmap='tab10')
plt.xlabel('PC 1')
plt.ylabel('PC 2')
plt.title('KMeans Clusters in PCA Space')
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 5))
axes[0].scatter(X_pca[:, 0], X_pca[:, 1], c=z_true, s=5)
axes[0].set_title('True Regimes')

axes[1].scatter(X_pca[:, 0], X_pca[:, 1], c=z_kmeans, s=5, cmap='tab10')
axes[0].set_title('KMeans Clusters')

plt.show()

# %%
ari = adjusted_rand_score(z_true, z_kmeans)
print(f'ARI: {ari:0.3f}')
# Out:
# ARI: 0.792
