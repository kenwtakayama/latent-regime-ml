# %%
import matplotlib.pyplot as plt
import sys, os
sys.path.append(os.path.abspath(".."))

from src.evaluation import calculate_ari
from src.models import fit_kmeans
from src.plotting import plot_PCA

# %store -r dataset
X = dataset[0]
z_true = dataset[1]
difficulty = dataset[2]
X_pca = dataset[3]

# %%
# Fit KMeans to PCA-transformed data

kmeans, z_kmeans = fit_kmeans(X_pca)

# %%
plot_PCA(X_pca, z_kmeans, 'KMeans Clustering Results', 3, difficulty, 'tab10')

# %%
# Plot true regimes vs KMeans clusters

fig, axes = plt.subplots(1, 2, figsize=(12, 5))
axes[0].scatter(X_pca[:, 0], X_pca[:, 1], c=z_true, s=5)
axes[0].set_title('True Regimes')

axes[1].scatter(X_pca[:, 0], X_pca[:, 1], c=z_kmeans, s=5, cmap='tab10')
axes[1].set_title('KMeans Clusters')

plt.show()

# %%
ari_kmeans = calculate_ari(z_true, z_kmeans, 'KMeans')
# Out:
# KMeans ARI: 0.381

# %%
results = [ari_kmeans, z_kmeans]
# %store results
del results
# Out:
# Stored 'results' (list)
