# %% [markdown]
# # PCA Reduction on Data

# %% [markdown]
# We apply PCA to extract latent factors prior to regime modeling.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import sys, os
sys.path.append(os.path.abspath(".."))

from src.evaluation import describe_PCA
from src.plotting import plot_PCA

# %store -r dataset
X = dataset[0]
z_true = dataset[1]
difficulty = dataset[2]

# %%
# Standardize features and apply PCA

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# %%
plot_PCA(X_pca, z_true, 'PCA Projection (Colored by True Regime)', 2, difficulty)

# %%
describe_PCA(pca)
# Out:
# Cumulative Explained Variance: 74.48%
# Explained Variance Ratio: [0.43  0.315]

# %%
dataset.append(X_pca)
# %store dataset
del dataset
# Out:
# Stored 'dataset' (list)
